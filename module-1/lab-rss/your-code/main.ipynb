# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
feedburner = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feedburner.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feedburner.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = feedburner.feed.title
subtitle = feedburner.feed.subtitle
author = feedburner.entries[0]['author']
link = feedburner.entries[0]['link']
print(title)
print(subtitle)
print(author)
print(link)
# Out:
# Radar
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
# Ben Lorica and Mike Loukides
# http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9PQAmHRa6oA/

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(feedburner.entries)
# Out:
# 18

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
components = [i for i in feedburner.feed.keys()]
components
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator',
#  'feedburner_info',
#  'geo_lat',
#  'geo_long',
#  'feedburner_emailserviceid',
#  'feedburner_feedburnerhostname']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
entry_titles = [feedburner.entries[i].title for i in range(len(feedburner.entries))]
entry_titles
# Out:
# ['A world of deepfakes',
#  'Radar trends to watch: November 2019',
#  'Four short links: 7 November 2019',
#  'Highlights from the O’Reilly Velocity Conference in Berlin 2019',
#  'Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#  'Modern machine learning architectures: Data and hardware and platform, oh my',
#  'The new norms of cloud native',
#  'Observability: Understanding production through your customers’ eyes',
#  'Secure reliable systems',
#  'My love letter to computer science is very short and I also forgot to mail it',
#  'Everything is a little bit broken; or, The illusion of control',
#  'Four short links: 6 November 2019',
#  'It’s important to cultivate your organization’s collective genius',
#  'Four short links: 5 November 2019',
#  'Four short links: 4 November 2019',
#  'Quantum computing’s potential is still far off, but quantum supremacy shows we’re on the right track',
#  'Four short links: 1 November 2019',
#  'Highlights from TensorFlow World in Santa Clara, California 2019']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
four_short_links = [e for e in lst if 'Four short links' in e]
percentage = len(four_short_links)/len(entry_titles)*100
print(round(percentage, 2), '%')
# Out:
# 27.78 %

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
entries = feedburner.entries
df = pd.DataFrame(entries)
df
# Out:
#                                                 title  \
# 0                                A world of deepfakes
# 1                Radar trends to watch: November 2019
# 2                   Four short links: 7 November 2019
# 3   Highlights from the O’Reilly Velocity Conferen...
# 4   Highlights from the O’Reilly Software Architec...
# 5   Modern machine learning architectures: Data an...
# 6                       The new norms of cloud native
# 7   Observability: Understanding production throug...
# 8                             Secure reliable systems
# 9   My love letter to computer science is very sho...
# 10  Everything is a little bit broken; or, The ill...
# 11                  Four short links: 6 November 2019
# 12  It’s important to cultivate your organization’...
# 13                  Four short links: 5 November 2019
# 14                  Four short links: 4 November 2019
# 15  Quantum computing’s potential is still far off...
# 16                  Four short links: 1 November 2019
# 17  Highlights from TensorFlow World in Santa Clar...
#
#                                          title_detail  \
# 0   {'type': 'text/plain', 'language': None, 'base...
# 1   {'type': 'text/plain', 'language': None, 'base...
# 2   {'type': 'text/plain', 'language': None, 'base...
# 3   {'type': 'text/plain', 'language': None, 'base...
# 4   {'type': 'text/plain', 'language': None, 'base...
# 5   {'type': 'text/plain', 'language': None, 'base...
# 6   {'type': 'text/plain', 'language': None, 'base...
# 7   {'type': 'text/plain', 'language': None, 'base...
# 8   {'type': 'text/plain', 'language': None, 'base...
# 9   {'type': 'text/plain', 'language': None, 'base...
# 10  {'type': 'text/plain', 'language': None, 'base...
# 11  {'type': 'text/plain', 'language': None, 'base...
# 12  {'type': 'text/plain', 'language': None, 'base...
# 13  {'type': 'text/plain', 'language': None, 'base...
# 14  {'type': 'text/plain', 'language': None, 'base...
# 15  {'type': 'text/plain', 'language': None, 'base...
# 16  {'type': 'text/plain', 'language': None, 'base...
# 17  {'type': 'text/plain', 'language': None, 'base...
#
#                                                 links  \
# 0   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 2   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 3   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 4   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 5   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 6   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 7   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 8   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 9   [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 10  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 11  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 12  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 13  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 14  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 15  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 16  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 17  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                  link  \
# 0   http://feedproxy.google.com/~r/oreilly/radar/a...
# 1   http://feedproxy.google.com/~r/oreilly/radar/a...
# 2   http://feedproxy.google.com/~r/oreilly/radar/a...
# 3   http://feedproxy.google.com/~r/oreilly/radar/a...
# 4   http://feedproxy.google.com/~r/oreilly/radar/a...
# 5   http://feedproxy.google.com/~r/oreilly/radar/a...
# 6   http://feedproxy.google.com/~r/oreilly/radar/a...
# 7   http://feedproxy.google.com/~r/oreilly/radar/a...
# 8   http://feedproxy.google.com/~r/oreilly/radar/a...
# 9   http://feedproxy.google.com/~r/oreilly/radar/a...
# 10  http://feedproxy.google.com/~r/oreilly/radar/a...
# 11  http://feedproxy.google.com/~r/oreilly/radar/a...
# 12  http://feedproxy.google.com/~r/oreilly/radar/a...
# 13  http://feedproxy.google.com/~r/oreilly/radar/a...
# 14  http://feedproxy.google.com/~r/oreilly/radar/a...
# 15  http://feedproxy.google.com/~r/oreilly/radar/a...
# 16  http://feedproxy.google.com/~r/oreilly/radar/a...
# 17  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                              comments  \
# 0   https://www.oreilly.com/radar/a-world-of-deepf...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 2   https://www.oreilly.com/radar/four-short-links...
# 3   https://www.oreilly.com/radar/highlights-from-...
# 4   https://www.oreilly.com/radar/highlights-from-...
# 5   https://www.oreilly.com/radar/modern-machine-l...
# 6   https://www.oreilly.com/radar/the-new-norms-of...
# 7   https://www.oreilly.com/radar/observability-un...
# 8   https://www.oreilly.com/radar/secure-reliable-...
# 9   https://www.oreilly.com/radar/my-love-letter-t...
# 10  https://www.oreilly.com/radar/everything-is-a-...
# 11  https://www.oreilly.com/radar/four-short-links...
# 12  https://www.oreilly.com/radar/its-important-to...
# 13  https://www.oreilly.com/radar/four-short-links...
# 14  https://www.oreilly.com/radar/four-short-links...
# 15  https://www.oreilly.com/radar/quantum-computin...
# 16  https://www.oreilly.com/radar/four-short-links...
# 17  https://www.oreilly.com/radar/highlights-from-...
#
#                           published                      published_parsed  \
# 0   Thu, 07 Nov 2019 14:00:50 +0000   (2019, 11, 7, 14, 0, 50, 3, 311, 0)
# 1   Thu, 07 Nov 2019 05:10:11 +0000   (2019, 11, 7, 5, 10, 11, 3, 311, 0)
# 2   Thu, 07 Nov 2019 05:01:24 +0000    (2019, 11, 7, 5, 1, 24, 3, 311, 0)
# 3   Wed, 06 Nov 2019 18:45:07 +0000   (2019, 11, 6, 18, 45, 7, 2, 310, 0)
# 4   Wed, 06 Nov 2019 18:40:44 +0000  (2019, 11, 6, 18, 40, 44, 2, 310, 0)
# 5   Wed, 06 Nov 2019 18:40:13 +0000  (2019, 11, 6, 18, 40, 13, 2, 310, 0)
# 6   Wed, 06 Nov 2019 18:40:10 +0000  (2019, 11, 6, 18, 40, 10, 2, 310, 0)
# 7   Wed, 06 Nov 2019 18:30:32 +0000  (2019, 11, 6, 18, 30, 32, 2, 310, 0)
# 8   Wed, 06 Nov 2019 18:30:29 +0000  (2019, 11, 6, 18, 30, 29, 2, 310, 0)
# 9   Wed, 06 Nov 2019 18:30:20 +0000  (2019, 11, 6, 18, 30, 20, 2, 310, 0)
# 10  Wed, 06 Nov 2019 18:30:10 +0000  (2019, 11, 6, 18, 30, 10, 2, 310, 0)
# 11  Wed, 06 Nov 2019 05:01:31 +0000    (2019, 11, 6, 5, 1, 31, 2, 310, 0)
# 12  Tue, 05 Nov 2019 05:05:36 +0000    (2019, 11, 5, 5, 5, 36, 1, 309, 0)
# 13  Tue, 05 Nov 2019 05:01:13 +0000    (2019, 11, 5, 5, 1, 13, 1, 309, 0)
# 14  Mon, 04 Nov 2019 05:01:01 +0000     (2019, 11, 4, 5, 1, 1, 0, 308, 0)
# 15  Fri, 01 Nov 2019 04:05:34 +0000    (2019, 11, 1, 4, 5, 34, 4, 305, 0)
# 16  Fri, 01 Nov 2019 04:01:53 +0000    (2019, 11, 1, 4, 1, 53, 4, 305, 0)
# 17  Fri, 01 Nov 2019 00:30:39 +0000   (2019, 11, 1, 0, 30, 39, 4, 305, 0)
#
#                                        authors                        author  \
# 0   [{'name': 'Ben Lorica and Mike Loukides'}]  Ben Lorica and Mike Loukides
# 1                  [{'name': 'Mike Loukides'}]                 Mike Loukides
# 2                 [{'name': 'Nat Torkington'}]                Nat Torkington
# 3                     [{'name': 'Mac Slocum'}]                    Mac Slocum
# 4                     [{'name': 'Mac Slocum'}]                    Mac Slocum
# 5                  [{'name': 'Brian Sletten'}]                 Brian Sletten
# 6                    [{'name': 'Cheryl Hung'}]                   Cheryl Hung
# 7                  [{'name': 'Christine Yen'}]                 Christine Yen
# 8                      [{'name': 'Ana Oprea'}]                     Ana Oprea
# 9                  [{'name': 'James Mickens'}]                 James Mickens
# 10              [{'name': 'Heidi Waterhouse'}]              Heidi Waterhouse
# 11                [{'name': 'Nat Torkington'}]                Nat Torkington
# 12                     [{'name': 'Jenn Webb'}]                     Jenn Webb
# 13                [{'name': 'Nat Torkington'}]                Nat Torkington
# 14                [{'name': 'Nat Torkington'}]                Nat Torkington
# 15                 [{'name': 'Mike Loukides'}]                 Mike Loukides
# 16                [{'name': 'Nat Torkington'}]                Nat Torkington
# 17                    [{'name': 'Mac Slocum'}]                    Mac Slocum
#
#                                author_detail  \
# 0   {'name': 'Ben Lorica and Mike Loukides'}
# 1                  {'name': 'Mike Loukides'}
# 2                 {'name': 'Nat Torkington'}
# 3                     {'name': 'Mac Slocum'}
# 4                     {'name': 'Mac Slocum'}
# 5                  {'name': 'Brian Sletten'}
# 6                    {'name': 'Cheryl Hung'}
# 7                  {'name': 'Christine Yen'}
# 8                      {'name': 'Ana Oprea'}
# 9                  {'name': 'James Mickens'}
# 10              {'name': 'Heidi Waterhouse'}
# 11                {'name': 'Nat Torkington'}
# 12                     {'name': 'Jenn Webb'}
# 13                {'name': 'Nat Torkington'}
# 14                {'name': 'Nat Torkington'}
# 15                 {'name': 'Mike Loukides'}
# 16                {'name': 'Nat Torkington'}
# 17                    {'name': 'Mac Slocum'}
#
#                                                  tags  \
# 0   [{'term': 'AI & ML', 'scheme': None, 'label': ...
# 1   [{'term': 'Radar Trends', 'scheme': None, 'lab...
# 2   [{'term': 'Four Short Links', 'scheme': None, ...
# 3   [{'term': 'Next Architecture', 'scheme': None,...
# 4   [{'term': 'Next Architecture', 'scheme': None,...
# 5   [{'term': 'Next Architecture', 'scheme': None,...
# 6   [{'term': 'Next Architecture', 'scheme': None,...
# 7   [{'term': 'Next Architecture', 'scheme': None,...
# 8   [{'term': 'Next Architecture', 'scheme': None,...
# 9   [{'term': 'Next Architecture', 'scheme': None,...
# 10  [{'term': 'Next Architecture', 'scheme': None,...
# 11  [{'term': 'Four Short Links', 'scheme': None, ...
# 12  [{'term': 'Future of the Firm', 'scheme': None...
# 13  [{'term': 'Four Short Links', 'scheme': None, ...
# 14  [{'term': 'Four Short Links', 'scheme': None, ...
# 15  [{'term': 'Innovation & Disruption', 'scheme':...
# 16  [{'term': 'Four Short Links', 'scheme': None, ...
# 17  [{'term': 'AI & ML', 'scheme': None, 'label': ...
#
#                                         id  guidislink  \
# 0   https://www.oreilly.com/radar/?p=10617       False
# 1   https://www.oreilly.com/radar/?p=10365       False
# 2   https://www.oreilly.com/radar/?p=10731       False
# 3   https://www.oreilly.com/radar/?p=10577       False
# 4   https://www.oreilly.com/radar/?p=10569       False
# 5   https://www.oreilly.com/radar/?p=10473       False
# 6   https://www.oreilly.com/radar/?p=10484       False
# 7   https://www.oreilly.com/radar/?p=10517       False
# 8   https://www.oreilly.com/radar/?p=10524       False
# 9   https://www.oreilly.com/radar/?p=10510       False
# 10  https://www.oreilly.com/radar/?p=10530       False
# 11  https://www.oreilly.com/radar/?p=10648       False
# 12  https://www.oreilly.com/radar/?p=10231       False
# 13  https://www.oreilly.com/radar/?p=10644       False
# 14  https://www.oreilly.com/radar/?p=10612       False
# 15  https://www.oreilly.com/radar/?p=10154       False
# 16  https://www.oreilly.com/radar/?p=10586       False
# 17  https://www.oreilly.com/radar/?p=10168       False
#
#                                               summary  \
# 0   Deepfakes have been very much in the news for ...
# 1   5G trends 5G networks get so much commentary t...
# 2   DNS Wars &#8212; But perhaps the position make...
# 3   People from across the cloud native and distri...
# 4   Experts from across the software architecture ...
# 5   This is a keynote highlight from the O&#8217;R...
# 6   This is a keynote highlight from the O&#8217;R...
# 7   This is a keynote highlight from the O&#8217;R...
# 8   This is a keynote highlight from the O&#8217;R...
# 9   This is a keynote highlight from the O&#8217;R...
# 10  This is a keynote highlight from the O&#8217;R...
# 11  Things I Wish Someone Had Explained About Func...
# 12  In this interview from O&#8217;Reilly Foo Camp...
# 13  &#8220;Nearly All&#8221; Counter-Strike Microt...
# 14  Beyond Bots and Trolls: Understanding Disinfor...
# 15  One of the most exciting topics we’ve been fol...
# 16  Vortimo &#8212; software that organizes inform...
# 17  People from across the TensorFlow community ca...
#
#                                        summary_detail  \
# 0   {'type': 'text/html', 'language': None, 'base'...
# 1   {'type': 'text/html', 'language': None, 'base'...
# 2   {'type': 'text/html', 'language': None, 'base'...
# 3   {'type': 'text/html', 'language': None, 'base'...
# 4   {'type': 'text/html', 'language': None, 'base'...
# 5   {'type': 'text/html', 'language': None, 'base'...
# 6   {'type': 'text/html', 'language': None, 'base'...
# 7   {'type': 'text/html', 'language': None, 'base'...
# 8   {'type': 'text/html', 'language': None, 'base'...
# 9   {'type': 'text/html', 'language': None, 'base'...
# 10  {'type': 'text/html', 'language': None, 'base'...
# 11  {'type': 'text/html', 'language': None, 'base'...
# 12  {'type': 'text/html', 'language': None, 'base'...
# 13  {'type': 'text/html', 'language': None, 'base'...
# 14  {'type': 'text/html', 'language': None, 'base'...
# 15  {'type': 'text/html', 'language': None, 'base'...
# 16  {'type': 'text/html', 'language': None, 'base'...
# 17  {'type': 'text/html', 'language': None, 'base'...
#
#                                               content  \
# 0   [{'type': 'text/html', 'language': None, 'base...
# 1   [{'type': 'text/html', 'language': None, 'base...
# 2   [{'type': 'text/html', 'language': None, 'base...
# 3   [{'type': 'text/html', 'language': None, 'base...
# 4   [{'type': 'text/html', 'language': None, 'base...
# 5   [{'type': 'text/html', 'language': None, 'base...
# 6   [{'type': 'text/html', 'language': None, 'base...
# 7   [{'type': 'text/html', 'language': None, 'base...
# 8   [{'type': 'text/html', 'language': None, 'base...
# 9   [{'type': 'text/html', 'language': None, 'base...
# 10  [{'type': 'text/html', 'language': None, 'base...
# 11  [{'type': 'text/html', 'language': None, 'base...
# 12  [{'type': 'text/html', 'language': None, 'base...
# 13  [{'type': 'text/html', 'language': None, 'base...
# 14  [{'type': 'text/html', 'language': None, 'base...
# 15  [{'type': 'text/html', 'language': None, 'base...
# 16  [{'type': 'text/html', 'language': None, 'base...
# 17  [{'type': 'text/html', 'language': None, 'base...
#
#                                        wfw_commentrss slash_comments  \
# 0   https://www.oreilly.com/radar/a-world-of-deepf...              0
# 1   https://www.oreilly.com/radar/radar-trends-to-...              0
# 2   https://www.oreilly.com/radar/four-short-links...              0
# 3   https://www.oreilly.com/radar/highlights-from-...              0
# 4   https://www.oreilly.com/radar/highlights-from-...              0
# 5   https://www.oreilly.com/radar/modern-machine-l...              0
# 6   https://www.oreilly.com/radar/the-new-norms-of...              0
# 7   https://www.oreilly.com/radar/observability-un...              0
# 8   https://www.oreilly.com/radar/secure-reliable-...              0
# 9   https://www.oreilly.com/radar/my-love-letter-t...              0
# 10  https://www.oreilly.com/radar/everything-is-a-...              0
# 11  https://www.oreilly.com/radar/four-short-links...              0
# 12  https://www.oreilly.com/radar/its-important-to...              0
# 13  https://www.oreilly.com/radar/four-short-links...              0
# 14  https://www.oreilly.com/radar/four-short-links...              0
# 15  https://www.oreilly.com/radar/quantum-computin...              0
# 16  https://www.oreilly.com/radar/four-short-links...              0
# 17  https://www.oreilly.com/radar/highlights-from-...              0
#
#                                   feedburner_origlink
# 0   https://www.oreilly.com/radar/a-world-of-deepf...
# 1   https://www.oreilly.com/radar/radar-trends-to-...
# 2   https://www.oreilly.com/radar/four-short-links...
# 3   https://www.oreilly.com/radar/highlights-from-...
# 4   https://www.oreilly.com/radar/highlights-from-...
# 5   https://www.oreilly.com/radar/modern-machine-l...
# 6   https://www.oreilly.com/radar/the-new-norms-of...
# 7   https://www.oreilly.com/radar/observability-un...
# 8   https://www.oreilly.com/radar/secure-reliable-...
# 9   https://www.oreilly.com/radar/my-love-letter-t...
# 10  https://www.oreilly.com/radar/everything-is-a-...
# 11  https://www.oreilly.com/radar/four-short-links...
# 12  https://www.oreilly.com/radar/its-important-to...
# 13  https://www.oreilly.com/radar/four-short-links...
# 14  https://www.oreilly.com/radar/four-short-links...
# 15  https://www.oreilly.com/radar/quantum-computin...
# 16  https://www.oreilly.com/radar/four-short-links...
# 17  https://www.oreilly.com/radar/highlights-from-...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                           author  entries
# 10                Nat Torkington        5
# 8                     Mac Slocum        3
# 9                  Mike Loukides        2
# 0                      Ana Oprea        1
# 1   Ben Lorica and Mike Loukides        1
# 2                  Brian Sletten        1
# 3                    Cheryl Hung        1
# 4                  Christine Yen        1
# 5               Heidi Waterhouse        1
# 6                  James Mickens        1
# 7                      Jenn Webb        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title', 'author', 'title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 15  Quantum computing’s potential is still far off...
# 9   My love letter to computer science is very sho...
# 4   Highlights from the O’Reilly Software Architec...
# 5   Modern machine learning architectures: Data an...
# 7   Observability: Understanding production throug...
# 12  It’s important to cultivate your organization’...
# 17  Highlights from TensorFlow World in Santa Clar...
# 3   Highlights from the O’Reilly Velocity Conferen...
# 10  Everything is a little bit broken; or, The ill...
# 1                Radar trends to watch: November 2019
# 11                  Four short links: 6 November 2019
# 13                  Four short links: 5 November 2019
# 14                  Four short links: 4 November 2019
# 2                   Four short links: 7 November 2019
# 16                  Four short links: 1 November 2019
# 6                       The new norms of cloud native
# 8                             Secure reliable systems
# 0                                A world of deepfakes
#
#                           author  title_length
# 15                 Mike Loukides           100
# 9                  James Mickens            77
# 4                     Mac Slocum            76
# 5                  Brian Sletten            76
# 7                  Christine Yen            68
# 12                     Jenn Webb            65
# 17                    Mac Slocum            64
# 3                     Mac Slocum            63
# 10              Heidi Waterhouse            62
# 1                  Mike Loukides            36
# 11                Nat Torkington            33
# 13                Nat Torkington            33
# 14                Nat Torkington            33
# 2                 Nat Torkington            33
# 16                Nat Torkington            33
# 6                    Cheryl Hung            29
# 8                      Ana Oprea            23
# 0   Ben Lorica and Mike Loukides            20

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
summaries = [feedburner.entries[i]['summary'] for i in range(len(feedburner.entries))]
dictionary = dict(zip(entry_titles, summaries))
text = "machine learning"
machine_learning = [i for i,j in dictionary.items() if text in j]
machine_learning
# Out:
# ['Highlights from the O’Reilly Software Architecture Conference in Berlin 2019',
#  'Highlights from TensorFlow World in Santa Clara, California 2019']
