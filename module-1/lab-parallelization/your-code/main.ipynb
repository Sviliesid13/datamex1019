# %% [markdown]
# # Parallelization Lab
#
# In this lab, you will be leveraging several concepts you have learned to obtain a list of links from a web page and crawl and index the pages referenced by those links - both sequentially and in parallel. Follow the steps below to complete the lab.

# %% [markdown]
# ## Step 1: Use the requests library to retrieve the content from the URL below.

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Data_science'

# %%
html = requests.get(url).content

# %% [markdown]
# ## Step 2: Use BeautifulSoup to extract a list of all the unique links on the page.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')
links = soup.find_all('a')
links_1 = [i.get('href') for i in links]
links_2 = list(set([str(i) for i in links_1]))
links_2
# Out:
# ['#cite_ref-:1_39-0',
#  '#cite_ref-Harvard_8-0',
#  '/wiki/U-Net',
#  '/wiki/Machine_Learning_(journal)',
#  '#cite_ref-cfjwu01_22-0',
#  '/wiki/Multi-disciplinary',
#  '#cite_ref-Harvard_8-1',
#  '#cite_note-37',
#  '#cite_note-18',
#  '/wiki/University_of_Michigan',
#  '/wiki/Datalogy',
#  '/wiki/Decision_tree_learning',
#  '/wiki/Regression_analysis',
#  '/wiki/Theory',
#  '#cite_note-45',
#  '#cite_note-:2-40',
#  '/wiki/Distributed_computing',
#  '#cite_ref-cfjwutk_21-0',
#  '//www.worldcat.org/issn/2245-408X',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Software_Developer',
#  '/wiki/Conditional_random_field',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  '//doi.org/10.1145%2F2500499',
#  '/wiki/Special:SpecialPages',
#  '/wiki/Artificial_neural_networks',
#  '#cite_note-GilPress-9',
#  '/wiki/Health_science',
#  '/wiki/Academic_publishing',
#  '#cite_ref-43',
#  '/wiki/Ensemble_learning',
#  '/wiki/Restricted_Boltzmann_machine',
#  '/wiki/Pattern_recognition',
#  '/wiki/Category:CS1_maint:_extra_text:_authors_list',
#  'https://hi.wikipedia.org/wiki/%E0%A4%86%E0%A4%81%E0%A4%95%E0%A4%A1%E0%A4%BC%E0%A4%BE_%E0%A4%B5%E0%A4%BF%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%A8',
#  'https://simple.wikipedia.org/wiki/Data_science',
#  '/wiki/International_Standard_Serial_Number',
#  '#cite_ref-Hayashi_4-1',
#  '/wiki/BIRCH',
#  '#cite_note-cfjwu01-22',
#  '/wiki/Category:Webarchive_template_wayback_links',
#  'http://www.statisticsviews.com/details/feature/5133141/Nate-Silver-What-I-need-from-statisticians.html',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  '#cite_ref-:2_40-3',
#  '/w/index.php?title=Data_science&action=edit&section=2',
#  '#cite_note-cleveland01-24',
#  'http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  '/wiki/Template_talk:Machine_learning_bar',
#  '/wiki/Boosting_(machine_learning)',
#  '/wiki/Turing_award',
#  'http://i.stanford.edu/~ullman/mmds/ch1n.pdf',
#  '/wiki/Database',
#  '/wiki/Anomaly_detection',
#  '/wiki/Temporal_difference_learning',
#  '/wiki/Category:All_articles_with_unsourced_statements',
#  '/wiki/Statistics',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  '#cite_ref-38',
#  'http://analytics-magazine.org/the-data-economy-why-do-so-many-analytics-projects-fail/',
#  '#cite_note-15',
#  '#cite_ref-dsj12_26-0',
#  '/wiki/Special:WhatLinksHere/Data_science',
#  '#cite_ref-Hayashi_4-0',
#  '/wiki/Linear_regression',
#  '/wiki/Supervised_learning',
#  '/wiki/Feature_engineering',
#  '/wiki/Feature_learning',
#  '#cite_ref-NateSilver_12-0',
#  '#cite_ref-18',
#  '/w/index.php?title=Data_science&action=info',
#  '//www.worldcat.org/issn/0036-8075',
#  '/wiki/Association_rule_learning',
#  '/wiki/Industry',
#  '#cite_ref-:3_3-0',
#  '/wiki/Big_data',
#  'https://en.wikipedia.org/w/index.php?title=Data_science&oldid=923200162',
#  '/wiki/Basic_research',
#  '#cite_note-31',
#  '#cite_note-14',
#  '/wiki/Long_short-term_memory',
#  '//doi.org/10.1007%2FBF00141776',
#  '#cite_note-ics12-25',
#  '#cite_ref-:2_40-6',
#  '//en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile',
#  '/wiki/Business_analytics',
#  '/wiki/Prasanta_Chandra_Mahalanobis',
#  '#cite_ref-TansleyTolle2009_5-1',
#  '/wiki/PubMed_Identifier',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Help:Contents',
#  '/wiki/Special:MyTalk',
#  '/wiki/Statistician',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '#cite_ref-37',
#  '/wiki/Naive_Bayes_classifier',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//www.worldcat.org/issn/0960-3174',
#  '#cite_ref-14',
#  'https://ta.wikipedia.org/wiki/%E0%AE%A4%E0%AE%B0%E0%AE%B5%E0%AF%81_%E0%AE%85%E0%AE%B1%E0%AE%BF%E0%AE%B5%E0%AE%BF%E0%AE%AF%E0%AE%B2%E0%AF%8D',
#  'https://fi.wikipedia.org/wiki/Datatiede',
#  '#cite_ref-42',
#  '/wiki/DeepDream',
#  '/wiki/Business_intelligence',
#  '//www.wikimediafoundation.org/',
#  'https://az.wikipedia.org/wiki/Veril%C9%99nl%C9%99r_elmi_(Data_Science)',
#  '#cite_ref-ics12_25-0',
#  '//www.worldcat.org/issn/0362-4331',
#  '#cite_ref-30',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia',
#  '/wiki/Statistical_learning_theory',
#  '/wiki/Jeffrey_T._Leek',
#  '/wiki/Talk:Data_science',
#  '#cite_ref-TansleyTolle2009_5-0',
#  '/wiki/Statistical_classification',
#  '#cite_note-ASA-34',
#  'http://radar.oreilly.com/2011/05/data-science-terminology.html',
#  '/wiki/Non-negative_matrix_factorization',
#  'https://nl.wikipedia.org/wiki/Datawetenschap',
#  '//doi.org/10.1145%2F365719.366510',
#  '/wiki/Category:Articles_with_unsourced_statements_from_April_2018',
#  '/wiki/K-means_clustering',
#  'https://pdfs.semanticscholar.org/915c/d8e2b39eb02723553913d592b2237d4d9960.pdf',
#  '//www.ncbi.nlm.nih.gov/pubmed/19535325',
#  '/wiki/Convolutional_neural_network',
#  'https://web.archive.org/web/20170205101231/http://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  '/wiki/Glossary_of_artificial_intelligence',
#  '#cite_note-41',
#  '/wiki/University_of_Essex',
#  '/wiki/David_Donoho',
#  '#cite_ref-BellHey2009_6-0',
#  '#cite_ref-ASA_34-0',
#  '/wiki/Canonical_correlation_analysis',
#  '#cite_note-Escoufier-19',
#  '#cite_note-cfjwutk-21',
#  '#cite_note-32',
#  '#cite_ref-41',
#  '/wiki/Computing',
#  '//doi.org/10.7146%2Fjod.9823',
#  '//www.ncbi.nlm.nih.gov/pmc/articles/PMC4058759',
#  '/wiki/Expectation%E2%80%93maximization_algorithm',
#  '#cite_note-7',
#  '/wiki/Social_science',
#  '/wiki/Grammar_induction',
#  '/wiki/Category:Computational_fields_of_study',
#  'https://wikimediafoundation.org/',
#  'https://ar.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%A7%D9%84%D8%A8%D9%8A%D8%A7%D9%86%D8%A7%D8%AA',
#  '#cite_ref-16',
#  'http://www.codata.org/',
#  '#cite_note-cfjwu02-23',
#  'http://fortune.com/2015/05/21/data-science-white-hot/',
#  '/wiki/Gated_recurrent_unit',
#  '/wiki/Principal_component_analysis',
#  '/wiki/Special:BookSources/978-3-319-72346-4',
#  '#cite_note-dsj02-27',
#  '/wiki/Academy',
#  '/wiki/Computer_science',
#  '/wiki/Q-learning',
#  '#cite_ref-:2_40-1',
#  '/wiki/DJ_Patil',
#  '/wiki/Applied_science',
#  'http://www.jstage.jst.go.jp/browse/dsj/_vols',
#  '#p-search',
#  '#cite_ref-jds03_28-0',
#  '/wiki/Empirical_research',
#  '/wiki/Main_Page',
#  '#cite_ref-cleveland01_24-1',
#  '#cite_note-33',
#  '/wiki/Buzzword',
#  'https://cs.wikipedia.org/wiki/Data_science',
#  '//www.worldcat.org/issn/1465-4644',
#  '#cite_note-Hayashi-4',
#  '/wiki/Probably_approximately_correct_learning',
#  '#cite_note-:0-1',
#  '/wiki/NYU_Stern_Center_for_Business_and_Human_Rights',
#  '/wiki/Bootstrap_aggregating',
#  '/wiki/Paradigm',
#  'https://www.nytimes.com/2011/04/03/business/03stream.html',
#  '/wiki/Wikipedia:General_disclaimer',
#  '/wiki/List_of_datasets_for_machine-learning_research',
#  '#cite_note-35',
#  'http://www.nsf.gov/pubs/2005/nsb0540/',
#  '/wiki/K-nearest_neighbors_algorithm',
#  '/wiki/Linear_discriminant_analysis',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '/wiki/Bayesian_network',
#  '/wiki/Wikipedia:Citation_needed',
#  '/wiki/Jeff_Hammerbacher',
#  '/wiki/Journal_of_Machine_Learning_Research',
#  'https://www.springer.com/book/9784431702085',
#  '#cite_ref-cfjwu02_23-0',
#  'https://zh-yue.wikipedia.org/wiki/%E6%95%B8%E6%93%9A%E7%A7%91%E5%AD%B8',
#  'https://web.archive.org/web/20170329172857/http://datamining.it.uts.edu.au/conferences/dsaa14/',
#  '/wiki/Hans_Rosling',
#  '/wiki/Information_explosion',
#  '#cite_ref-:0_1-0',
#  '/wiki/Cluster_analysis',
#  '#cite_ref-BellHey2009_6-1',
#  '/wiki/CURE_data_clustering_algorithm',
#  'http://www.jstage.jst.go.jp/browse/dsj/1/0/_contents',
#  '/wiki/Software_engineer',
#  '/w/index.php?title=Data_science&action=history',
#  '/wiki/Special:BookSources/978-0-9825442-0-4',
#  '/wiki/Reinforcement_learning',
#  'http://euads.org',
#  'https://www.consultancy.uk/news/16839/70-of-big-data-projects-in-uk-fail-to-realise-full-potential',
#  '#cite_ref-:2_40-2',
#  '/wiki/New_York_University',
#  '#cite_ref-Dinov_DSPA_2018_10-0',
#  'https://books.google.com/books?id=oGs_AQAAIAAJ',
#  '/wiki/Hierarchical_clustering',
#  '/wiki/Anand_Rajaraman',
#  '/wiki/Artificial_neural_network',
#  '//doi.org/10.1007%2F978-4-431-65950-1_3',
#  '#cite_note-44',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  '/wiki/Special:MyContributions',
#  '//doi.org/10.1016%2Fj.ipm.2017.05.004',
#  '/wiki/Automated_machine_learning',
#  '//www.worldcat.org/issn/0028-0836',
#  '/wiki/Conference_on_Neural_Information_Processing_Systems',
#  '/wiki/Perceptron',
#  '#cite_note-jds03-28',
#  '/wiki/Category:Use_dmy_dates_from_December_2012',
#  '/wiki/Category:Data_analysis',
#  'https://commons.wikimedia.org/wiki/Category:Data_science',
#  '#cite_note-:3-3',
#  'https://web.archive.org/web/20131029191813/http://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  '/wiki/Jim_Gray_(computer_scientist)',
#  '/wiki/Computational_learning_theory',
#  '/wiki/Statistical_theory',
#  '//www.ncbi.nlm.nih.gov/pubmed/24482835',
#  'https://www.springer.com/41060',
#  '/wiki/Deep_learning',
#  '#cite_note-13',
#  '#cite_note-42',
#  '#cite_ref-17',
#  '/wiki/PubMed_Central',
#  '/wiki/Portal:Current_events',
#  'https://he.wikipedia.org/wiki/%D7%9E%D7%93%D7%A2_%D7%94%D7%A0%D7%AA%D7%95%D7%A0%D7%99%D7%9D',
#  '/wiki/Nate_Silver',
#  '#cite_ref-36',
#  '#cite_ref-7',
#  '/wiki/Jeffrey_David_Ullman',
#  'http://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  '/wiki/Factor_analysis',
#  '/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Data+science',
#  '#cite_note-Harvard-8',
#  '#mw-head',
#  '#cite_note-dsj12-26',
#  '/wiki/Data_set',
#  '/wiki/Special:BookSources/9784431702085',
#  '/wiki/Recurrent_neural_network',
#  '/wiki/Data',
#  '/wiki/DBSCAN',
#  '/wiki/Learning_to_rank',
#  '/wiki/Multilayer_perceptron',
#  '/wiki/Data_analysis',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BF%D1%80%D0%BE_%D0%B4%D0%B0%D0%BD%D1%96',
#  '#cite_ref-13',
#  'http://www.gfkl.org/welcome/',
#  '/wiki/State%E2%80%93action%E2%80%93reward%E2%80%93state%E2%80%93action',
#  '/wiki/Vapnik%E2%80%93Chervonenkis_theory',
#  '/wiki/Dimensionality_reduction',
#  '//doi.org/10.1093%2Fbiostatistics%2Fkxp014',
#  '//www.ncbi.nlm.nih.gov/pubmed/24436391',
#  'https://www.nytimes.com/2009/12/15/science/15books.html',
#  'http://www.dsaa.co',
#  '#cite_ref-NateSilver_12-1',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463',
#  '#cite_note-TansleyTolle2009-5',
#  '#cite_note-20',
#  '/wiki/American_Statistical_Association',
#  '/wiki/Peter_Naur',
#  'http://www.jds-online.com/v1-1',
#  '#cite_note-36',
#  '/wiki/Semi-supervised_learning',
#  '/wiki/Mean-shift',
#  '//creativecommons.org/licenses/by-sa/3.0/',
#  '#cite_ref-44',
#  '/wiki/K-nearest_neighbors_classification',
#  '#cite_ref-20',
#  '/wiki/Structured_prediction',
#  'http://ur.umich.edu/9899/Nov09_98/4.htm',
#  '/w/index.php?title=Special:CiteThisPage&page=Data_science&id=923200162',
#  '#cite_note-2',
#  'https://el.wikipedia.org/wiki/%CE%95%CF%80%CE%B9%CF%83%CF%84%CE%AE%CE%BC%CE%B7_%CE%B4%CE%B5%CE%B4%CE%BF%CE%BC%CE%AD%CE%BD%CF%89%CE%BD',
#  'http://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  '#cite_note-43',
#  '/wiki/Jure_Leskovec',
#  '/wiki/Local_outlier_factor',
#  '#cite_note-BellHey2009-6',
#  '#cite_ref-11',
#  '#cite_ref-cfjwutk_21-1',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  '/wiki/The_Wall_Street_Journal',
#  '/wiki/Occam_learning',
#  'https://ru.wikipedia.org/wiki/%D0%9D%D0%B0%D1%83%D0%BA%D0%B0_%D0%BE_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85',
#  '/wiki/Academic_journal',
#  '/wiki/Predictive_modelling',
#  '/wiki/Machine_learning',
#  '/w/index.php?title=Data_science&action=edit&section=3',
#  '/wiki/Analytics',
#  '/wiki/T-distributed_stochastic_neighbor_embedding',
#  'https://web.archive.org/web/20120403153707/http://www.jstage.jst.go.jp/browse/dsj/_vols',
#  '/wiki/Special:BookSources/0-12-241770-4',
#  '#cite_ref-cleveland01_24-0',
#  '/wiki/Autoencoder',
#  '/wiki/International_Standard_Book_Number',
#  'https://www.kdnuggets.com/2018/05/data-science-4-reasons-failing-deliver.html',
#  '/wiki/Data_science',
#  '/wiki/Thomas_H._Davenport',
#  '/wiki/Independent_component_analysis',
#  'https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9',
#  '#cite_note-30',
#  'http://datamining.it.uts.edu.au/conferences/dsaa14/',
#  '/wiki/Portal:Featured_content',
#  '/wiki/Montpellier_2_University',
#  '/w/index.php?title=Special:CreateAccount&returnto=Data+science',
#  '/wiki/Wayback_Machine',
#  '#cite_ref-GilPress_9-1',
#  'https://pt.wikipedia.org/wiki/Ci%C3%AAncia_de_dados',
#  'https://www.mediawiki.org/',
#  'https://ko.wikipedia.org/wiki/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%82%AC%EC%9D%B4%EC%96%B8%EC%8A%A4',
#  '/wiki/C.F._Jeff_Wu',
#  '/wiki/Open_science',
#  '/wiki/Empirical_risk_minimization',
#  '//www.ncbi.nlm.nih.gov/pubmed/19265007',
#  '/wiki/National_Institutes_of_Health',
#  '#cite_note-16',
#  '#cite_ref-:2_40-5',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Indian_Statistical_Institute',
#  '#cite_note-11',
#  '/wiki/Portal:Contents',
#  '/wiki/File:Kernel_Machine.svg',
#  'https://en.wikipedia.org/w/index.php?title=Template:Machine_learning_bar&action=edit',
#  'https://www.bbc.co.uk/programmes/b00wgq0l',
#  '/w/index.php?title=Data_science&action=edit&section=1',
#  '#cite_ref-:3_3-1',
#  '/w/index.php?title=Special:UserLogin&returnto=Data+science',
#  '#cite_note-17',
#  '/wiki/Generative_adversarial_network',
#  '/wiki/Discipline_(academia)',
#  '//doi.org/10.1126%2Fscience.1170411',
#  'None',
#  '/wiki/Forbes',
#  'https://zh.wikipedia.org/wiki/%E6%95%B0%E6%8D%AE%E7%A7%91%E5%AD%A6',
#  '/wiki/Outline_of_machine_learning',
#  '/wiki/Graphical_model',
#  '#cite_ref-2',
#  '/wiki/Data_mining',
#  '#cite_ref-GilPress_9-0',
#  '/w/index.php?title=Special:ElectronPdf&page=Data+science&action=show-download-screen',
#  '#cite_ref-45',
#  '#cite_note-38',
#  'https://fr.wikipedia.org/wiki/Science_des_donn%C3%A9es',
#  '#cite_note-Dinov_DSPA_2018-10',
#  '#cite_ref-dsj02_27-0',
#  '#cite_ref-:0_1-1',
#  '/wiki/General_Assembly_(school)',
#  'https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/',
#  '#cite_ref-:2_40-0',
#  '#cite_ref-Escoufier_19-0',
#  'https://blogs.wsj.com/cio/2014/05/02/why-do-we-need-data-science-when-weve-had-statistics-for-centuries/',
#  '/w/index.php?title=Data_science&oldid=923200162',
#  '/wiki/Help:Category',
#  'http://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  '//doi.org/10.1038%2F505612a',
#  '/wiki/Interdisciplinarity',
#  'https://hy.wikipedia.org/wiki/%D5%8F%D5%BE%D5%B5%D5%A1%D5%AC%D5%B6%D5%A5%D6%80%D5%AB_%D5%A3%D5%AB%D5%BF%D5%B8%D6%82%D5%A9%D5%B5%D5%B8%D6%82%D5%B6',
#  '/wiki/The_Data_Incubator',
#  'https://it.wikipedia.org/wiki/Scienza_dei_dati',
#  '/wiki/Support-vector_machine',
#  '/wiki/Logistic_regression',
#  '/wiki/Hidden_Markov_model',
#  '#cite_ref-35',
#  'https://arxiv.org/list/cs.LG/recent',
#  'https://ms.wikipedia.org/wiki/Sains_data',
#  'https://vi.wikipedia.org/wiki/Khoa_h%E1%BB%8Dc_d%E1%BB%AF_li%E1%BB%87u',
#  '/w/index.php?title=Data_science&printable=yes',
#  '#cite_ref-29',
#  '#cite_ref-:2_40-7',
#  '#cite_ref-GilPress_9-2',
#  'https://es.wikipedia.org/wiki/Ciencia_de_datos',
#  'https://de.wikipedia.org/wiki/Data_Science',
#  '/wiki/Template:Machine_learning_bar',
#  '//doi.org/10.1126%2Fscience.1250475',
#  '#cite_ref-15',
#  '/wiki/Explanatory_model',
#  '/wiki/Unsupervised_learning',
#  'https://books.google.com/books?id=zdBXAQAAQBAJ&printsec=frontcover#v=onepage&q=%22data%20science%22&f=false',
#  '/wiki/Random_forest',
#  'https://lv.wikipedia.org/wiki/Datu_m%C4%81c%C4%ABba',
#  '//shop.wikimedia.org',
#  '/wiki/Special:RecentChangesLinked/Data_science',
#  '/wiki/Digital_object_identifier',
#  '/wiki/Category:Computer_occupations',
#  '/wiki/Online_machine_learning',
#  '/wiki/Methodology',
#  '#cite_note-29',
#  '/w/index.php?title=Data_science&action=edit',
#  '/wiki/Special:Random',
#  '#cite_ref-:0_1-2',
#  '/wiki/Relevance_vector_machine',
#  '/wiki/Knowledge',
#  'http://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  '/wiki/OPTICS_algorithm',
#  '#cite_ref-32',
#  'https://id.wikipedia.org/wiki/Ilmu_data',
#  '#cite_note-:1-39',
#  'https://venturebeat.com/2014/04/15/ny-gets-new-bootcamp-for-data-scientists-its-free-but-harder-to-get-into-than-harvard/',
#  '#cite_ref-:2_40-4',
#  '/wiki/Graduate_school',
#  'https://hbr.org/2018/01/are-you-setting-your-data-scientists-up-to-fail',
#  'https://fa.wikipedia.org/wiki/%D8%B9%D9%84%D9%85_%D8%AF%D8%A7%D8%AF%D9%87%E2%80%8C%D9%87%D8%A7',
#  '/wiki/Mathematics',
#  '/wiki/International_Conference_on_Machine_Learning',
#  'https://my.wikipedia.org/wiki/%E1%80%A1%E1%80%81%E1%80%BB%E1%80%80%E1%80%BA%E1%80%A1%E1%80%9C%E1%80%80%E1%80%BA%E1%80%9E%E1%80%AD%E1%80%95%E1%80%B9%E1%80%95%E1%80%B6%E1%80%95%E1%80%8A%E1%80%AC',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '#cite_ref-:1_39-1',
#  '/wiki/Wikipedia:About',
#  '/wiki/Information_science',
#  '/wiki/Computational_science',
#  '/wiki/Harvard_Business_Review',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Bias%E2%80%93variance_dilemma',
#  '#cite_ref-33',
#  'https://ca.wikipedia.org/wiki/Ci%C3%A8ncia_de_les_dades',
#  'http://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  '#cite_note-NateSilver-12',
#  '/wiki/Self-organizing_map',
#  '/wiki/Category:Information_science',
#  '#cite_ref-31']

# %% [markdown]
# ## Step 3: Use list comprehensions with conditions to clean the link list.
#
# There are two types of links, absolute and relative. Absolute links have the full URL and begin with http while relative links begin with a forward slash (/) and point to an internal page within the wikipedia.org domain. Clean the respective types of URLs as follows.
#
# - Absolute Links: Create a list of these and remove any that contain a percentage sign (%).
# - Relativel Links: Create a list of these, add the domain to the link so that you have the full URL, and remove any that contain a percentage sign (%).
# - Combine the list of absolute and relative links and ensure there are no duplicates.

# %%
domain = 'http://wikipedia.org'

# %%
absolute = [i for i in links_2 if 'http' in i]
absolute_1 = [i for i in absolute if '%' not in i]
relative = [i for i in links_2 if i not in absolute]
relative_2 = [domain+i for i in relative]
relative_3 = [i for i in relative_2 if '%' not in i]
combine = list(set(absolute_1+relative_3))
combine_2 = [i.replace('http', 'https').replace('httpss','https') for i in combine]
combine_2
# Out:
# ['https://wikipedia.org/wiki/Factor_analysis',
#  'https://wikipedia.org#cite_ref-BellHey2009_6-1',
#  'https://wikipedia.org/wiki/Open_science',
#  'https://wikipedia.org#p-search',
#  'https://wikipedia.org/wiki/Local_outlier_factor',
#  'https://wikipedia.org#cite_note-29',
#  'https://wikipedia.org#cite_ref-:0_1-2',
#  'https://wikipedia.org#cite_note-37',
#  'https://wikipedia.org#cite_note-jds03-28',
#  'https://hbr.org/2012/10/data-scientist-the-sexiest-job-of-the-21st-century/',
#  'https://wikipedia.org/wiki/BIRCH',
#  'https://wikipedia.org#cite_ref-Hayashi_4-0',
#  'https://wikipedia.org#cite_note-31',
#  'https://simple.wikipedia.org/wiki/Data_science',
#  'https://wikipedia.org#cite_ref-:3_3-1',
#  'https://wikipedia.org#cite_ref-dsj02_27-0',
#  'https://wikipedia.org/wiki/Wikipedia:Community_portal',
#  'https://wikipedia.org/wiki/Special:WhatLinksHere/Data_science',
#  'https://wikipedia.org/wiki/American_Statistical_Association',
#  'https://wikipedia.org//foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://www.statisticsviews.com/details/feature/5133141/Nate-Silver-What-I-need-from-statisticians.html',
#  'https://wikipedia.org/wiki/Supervised_learning',
#  'https://wikipedia.org#cite_ref-:1_39-0',
#  'https://wikipedia.org/wiki/Buzzword',
#  'https://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf',
#  'https://i.stanford.edu/~ullman/mmds/ch1n.pdf',
#  'https://wikipedia.org/wiki/Machine_Learning_(journal)',
#  'https://wikipedia.org/wiki/Wikipedia:General_disclaimer',
#  'https://magazine.amstat.org/blog/2015/10/01/asa-statement-on-the-role-of-statistics-in-data-science/',
#  'https://wikipedia.org/wiki/Template_talk:Machine_learning_bar',
#  'https://analytics-magazine.org/the-data-economy-why-do-so-many-analytics-projects-fail/',
#  'https://wikipedia.org/wiki/Bayesian_network',
#  'https://wikipedia.org/wiki/Template:Machine_learning_bar',
#  'https://wikipedia.org/wiki/Bootstrap_aggregating',
#  'https://wikipedia.org/wiki/Special:MyContributions',
#  'https://wikipedia.org#cite_note-45',
#  'https://wikipedia.org/wiki/Non-negative_matrix_factorization',
#  'https://wikipedia.org/wiki/Recurrent_neural_network',
#  'https://en.wikipedia.org/w/index.php?title=Data_science&oldid=923200162',
#  'https://wikipedia.org/wiki/Indian_Statistical_Institute',
#  'https://wikipedia.org/wiki/Graphical_model',
#  'https://wikipedia.org/wiki/Generative_adversarial_network',
#  'https://wikipedia.org/wiki/Academic_journal',
#  'https://wikipedia.org/wiki/Industry',
#  'https://wikipedia.org//shop.wikimedia.org',
#  'https://wikipedia.org#cite_note-38',
#  'https://wikipedia.org/wiki/Journal_of_Machine_Learning_Research',
#  'https://wikipedia.org/wiki/Special:BookSources/9784431702085',
#  'https://wikipedia.org/wiki/Empirical_risk_minimization',
#  'https://wikipedia.org/wiki/Wikipedia:Citation_needed',
#  'https://wikipedia.org/wiki/Association_rule_learning',
#  'https://wikipedia.org/wiki/NYU_Stern_Center_for_Business_and_Human_Rights',
#  'https://wikipedia.org#cite_ref-ics12_25-0',
#  'https://wikipedia.org#cite_ref-Harvard_8-0',
#  'https://wikipedia.org/wiki/Multi-disciplinary',
#  'https://wikipedia.org/wiki/Online_machine_learning',
#  'https://wikipedia.org#cite_ref-:0_1-1',
#  'https://wikipedia.org/wiki/Special:SpecialPages',
#  'https://wikipedia.org/wiki/Hierarchical_clustering',
#  'https://wikipedia.org#cite_note-ics12-25',
#  'https://wikipedia.org#cite_ref-Hayashi_4-1',
#  'https://wikipedia.org/wiki/Conditional_random_field',
#  'https://wikipedia.org/wiki/Special:MyTalk',
#  'https://wikipedia.org/wiki/Anomaly_detection',
#  'https://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  'https://wikipedia.org/wiki/Academy',
#  'https://wikipedia.org/w/index.php?title=Data_science&printable=yes',
#  'https://wikipedia.org//www.ncbi.nlm.nih.gov/pubmed/19535325',
#  'https://wikipedia.org/wiki/Artificial_neural_networks',
#  'https://wikipedia.org#cite_note-7',
#  'https://wikipedia.org/wiki/Occam_learning',
#  'https://wikipedia.org#cite_note-36',
#  'https://wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Data_science&id=923200162',
#  'https://fi.wikipedia.org/wiki/Datatiede',
#  'https://wikipedia.org#cite_note-11',
#  'https://wikipedia.org/wiki/PubMed_Identifier',
#  'https://wikipedia.org/wiki/University_of_Essex',
#  'https://wikipedia.org/wiki/Knowledge',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463#sitelinks-wikipedia',
#  'https://wikipedia.org#cite_note-TansleyTolle2009-5',
#  'https://wikipedia.org//www.ncbi.nlm.nih.gov/pubmed/19265007',
#  'https://wikipedia.org#cite_ref-GilPress_9-2',
#  'https://wikipedia.org#cite_ref-20',
#  'https://wikipedia.org/wiki/Unsupervised_learning',
#  'https://wikipedia.org#cite_ref-TansleyTolle2009_5-1',
#  'https://wikipedia.org#cite_note-43',
#  'https://wikipedia.org#cite_ref-jds03_28-0',
#  'https://wikipedia.org#cite_note-13',
#  'https://wikipedia.org/wiki/Category:Information_science',
#  'https://radar.oreilly.com/2011/05/data-science-terminology.html',
#  'https://wikipedia.org/wiki/Temporal_difference_learning',
#  'https://nl.wikipedia.org/wiki/Datawetenschap',
#  'https://wikipedia.org/wiki/Discipline_(academia)',
#  'https://wikipedia.org#cite_ref-NateSilver_12-1',
#  'https://wikipedia.org/wiki/Data_analysis',
#  'https://pdfs.semanticscholar.org/915c/d8e2b39eb02723553913d592b2237d4d9960.pdf',
#  'https://web.archive.org/web/20170205101231/https://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  'https://wikipedia.org#cite_note-NateSilver-12',
#  'https://wikipedia.org#cite_ref-:1_39-1',
#  'https://wikipedia.org#cite_note-dsj12-26',
#  'https://wikipedia.org#cite_ref-44',
#  'https://wikipedia.org/wiki/K-means_clustering',
#  'https://wikipedia.org#cite_note-44',
#  'https://wikipedia.org#cite_note-dsj02-27',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=info',
#  'https://wikipedia.org#cite_note-:0-1',
#  'https://wikipedia.org/wiki/Pattern_recognition',
#  'https://wikipedia.org#cite_note-cfjwu02-23',
#  'https://wikipedia.org/wiki/Learning_to_rank',
#  'https://wikipedia.org#cite_ref-:2_40-0',
#  'https://wikipedia.org/wiki/Turing_award',
#  'https://wikipedia.org#cite_ref-cfjwutk_21-1',
#  'https://wikipedia.org/wiki/Thomas_H._Davenport',
#  'https://wikimediafoundation.org/',
#  'https://wikipedia.org/wiki/Cluster_analysis',
#  'https://wikipedia.org//www.worldcat.org/issn/0028-0836',
#  'https://www.codata.org/',
#  'https://wikipedia.org#cite_ref-cfjwu01_22-0',
#  'https://fortune.com/2015/05/21/data-science-white-hot/',
#  'https://wikipedia.org/wiki/Computer_science',
#  'https://wikipedia.org/wiki/CURE_data_clustering_algorithm',
#  'https://wikipedia.org/wiki/Random_forest',
#  'https://wikipedia.org#cite_ref-:3_3-0',
#  'https://wikipedia.org/wiki/Special:BookSources/978-3-319-72346-4',
#  'https://wikipedia.org#cite_ref-:2_40-6',
#  'https://wikipedia.org#cite_note-35',
#  'https://wikipedia.org/wiki/Structured_prediction',
#  'https://wikipedia.org#cite_ref-38',
#  'https://www.jstage.jst.go.jp/browse/dsj/_vols',
#  'https://wikipedia.org/wiki/Software_engineer',
#  'https://wikipedia.org/wiki/Information_science',
#  'https://wikipedia.org/wiki/Business_intelligence',
#  'https://wikipedia.org#cite_ref-13',
#  'https://wikipedia.org#cite_ref-:2_40-3',
#  'https://wikipedia.org#cite_ref-:2_40-2',
#  'https://cs.wikipedia.org/wiki/Data_science',
#  'https://wikipedia.org#cite_ref-cfjwu02_23-0',
#  'https://wikipedia.org/wiki/Portal:Contents',
#  'https://wikipedia.org#cite_ref-16',
#  'https://wikipedia.orgNone',
#  'https://wikipedia.org#cite_ref-35',
#  'https://wikipedia.org//www.worldcat.org/issn/0362-4331',
#  'https://wikipedia.org/wiki/Mathematics',
#  'https://www.nytimes.com/2011/04/03/business/03stream.html',
#  'https://wikipedia.org//www.worldcat.org/issn/0036-8075',
#  'https://wikipedia.org//en.m.wikipedia.org/w/index.php?title=Data_science&mobileaction=toggle_view_mobile',
#  'https://wikipedia.org#cite_note-cleveland01-24',
#  'https://wikipedia.org/wiki/Multilayer_perceptron',
#  'https://wikipedia.org#cite_ref-NateSilver_12-0',
#  'https://wikipedia.org/wiki/Applied_science',
#  'https://wikipedia.org/wiki/Category:Data_analysis',
#  'https://wikipedia.org#cite_ref-GilPress_9-1',
#  'https://www.nsf.gov/pubs/2005/nsb0540/',
#  'https://wikipedia.org/wiki/Interdisciplinarity',
#  'https://wikipedia.org/wiki/U-Net',
#  'https://wikipedia.org#cite_ref-2',
#  'https://wikipedia.org#cite_note-:1-39',
#  'https://wikipedia.org/wiki/National_Institutes_of_Health',
#  'https://wikipedia.org/wiki/Category:Computational_fields_of_study',
#  'https://wikipedia.org/wiki/Academic_publishing',
#  'https://wikipedia.org/wiki/Linear_discriminant_analysis',
#  'https://wikipedia.org#cite_ref-36',
#  'https://www.springer.com/book/9784431702085',
#  'https://wikipedia.org#cite_note-BellHey2009-6',
#  'https://web.archive.org/web/20170329172857/https://datamining.it.uts.edu.au/conferences/dsaa14/',
#  'https://wikipedia.org/wiki/Outline_of_machine_learning',
#  'https://wikipedia.org#cite_ref-Escoufier_19-0',
#  'https://wikipedia.org#cite_note-20',
#  'https://wikipedia.org/wiki/Software_Developer',
#  'https://www.jstage.jst.go.jp/browse/dsj/1/0/_contents',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=edit',
#  'https://wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_April_2018',
#  'https://euads.org',
#  'https://wikipedia.org/wiki/Autoencoder',
#  'https://www.consultancy.uk/news/16839/70-of-big-data-projects-in-uk-fail-to-realise-full-potential',
#  'https://wikipedia.org#cite_note-cfjwutk-21',
#  'https://wikipedia.org/wiki/Special:Random',
#  'https://books.google.com/books?id=oGs_AQAAIAAJ',
#  'https://wikipedia.org/wiki/Empirical_research',
#  'https://wikipedia.org/wiki/Statistician',
#  'https://www.forbes.com/sites/gilpress/2013/05/28/a-very-short-history-of-data-science/',
#  'https://wikipedia.org/wiki/Special:BookSources/978-0-9825442-0-4',
#  'https://wikipedia.org/wiki/Special:RecentChanges',
#  'https://wikipedia.org#cite_note-18',
#  'https://wikipedia.org#cite_ref-29',
#  'https://wikipedia.org/wiki/Statistics',
#  'https://wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Data+science',
#  'https://wikipedia.org/wiki/Theory',
#  'https://wikipedia.org/wiki/Statistical_classification',
#  'https://wikipedia.org/wiki/Main_Page',
#  'https://wikipedia.org#cite_note-Harvard-8',
#  'https://wikipedia.org/wiki/Gated_recurrent_unit',
#  'https://wikipedia.org/wiki/K-nearest_neighbors_classification',
#  'https://wikipedia.org/wiki/Jeff_Hammerbacher',
#  'https://commons.wikimedia.org/wiki/Category:Data_science',
#  'https://wikipedia.org/wiki/Naive_Bayes_classifier',
#  'https://wikipedia.org/wiki/DeepDream',
#  'https://web.archive.org/web/20131029191813/https://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  'https://wikipedia.org/wiki/Reinforcement_learning',
#  'https://wikipedia.org#cite_ref-32',
#  'https://wikipedia.org/w/index.php?title=Special:ElectronPdf&page=Data+science&action=show-download-screen',
#  'https://wikipedia.org/wiki/General_Assembly_(school)',
#  'https://www.springer.com/41060',
#  'https://wikipedia.org#cite_ref-45',
#  'https://wikipedia.org/wiki/Q-learning',
#  'https://wikipedia.org/wiki/Forbes',
#  'https://wikipedia.org#cite_ref-33',
#  'https://magazine.amstat.org/blog/2016/06/01/datascience-2/',
#  'https://wikipedia.org//foundation.wikimedia.org/wiki/Terms_of_Use',
#  'https://wikipedia.org/wiki/University_of_Michigan',
#  'https://wikipedia.org#cite_ref-18',
#  'https://wikipedia.org#cite_ref-15',
#  'https://wikipedia.org#cite_note-ASA-34',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://wikipedia.org/wiki/Business_analytics',
#  'https://wikipedia.org/wiki/Special:RecentChangesLinked/Data_science',
#  'https://wikipedia.org/wiki/Category:CS1_maint:_extra_text:_authors_list',
#  'https://wikipedia.org/wiki/Canonical_correlation_analysis',
#  'https://wikipedia.org/wiki/Statistical_theory',
#  'https://www.gfkl.org/welcome/',
#  'https://wikipedia.org//www.wikimediafoundation.org/',
#  'https://wikipedia.org/wiki/Ensemble_learning',
#  'https://wikipedia.org/wiki/Jim_Gray_(computer_scientist)',
#  'https://www.nytimes.com/2009/12/15/science/15books.html',
#  'https://www.dsaa.co',
#  'https://wikipedia.org#cite_ref-BellHey2009_6-0',
#  'https://wikipedia.org/wiki/Data_science',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q2374463',
#  'https://wikipedia.org/wiki/Portal:Current_events',
#  'https://wikipedia.org/wiki/Portal:Featured_content',
#  'https://wikipedia.org/wiki/Perceptron',
#  'https://wikipedia.org/wiki/Jeffrey_T._Leek',
#  'https://wikipedia.org/wiki/Explanatory_model',
#  'https://wikipedia.org/wiki/Paradigm',
#  'https://www.jds-online.com/v1-1',
#  'https://wikipedia.org/wiki/Graduate_school',
#  'https://wikipedia.org/wiki/Self-organizing_map',
#  'https://wikipedia.org//www.worldcat.org/issn/2245-408X',
#  'https://wikipedia.org#cite_note-30',
#  'https://ur.umich.edu/9899/Nov09_98/4.htm',
#  'https://wikipedia.org#cite_ref-cleveland01_24-1',
#  'https://wikipedia.org#cite_ref-ASA_34-0',
#  'https://www2.isye.gatech.edu/~jeffwu/presentations/datascience.pdf',
#  'https://wikipedia.org/wiki/Glossary_of_artificial_intelligence',
#  'https://wikipedia.org/wiki/Automated_machine_learning',
#  'https://wikipedia.org#cite_note-Escoufier-19',
#  'https://wikipedia.org/wiki/Big_data',
#  'https://wikipedia.org#cite_ref-cfjwutk_21-0',
#  'https://wikipedia.org/wiki/Convolutional_neural_network',
#  'https://wikipedia.org/wiki/Anand_Rajaraman',
#  'https://wikipedia.org#cite_ref-GilPress_9-0',
#  'https://wikipedia.org/wiki/Talk:Data_science',
#  'https://wikipedia.org//www.ncbi.nlm.nih.gov/pubmed/24482835',
#  'https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute',
#  'https://wikipedia.org/wiki/Distributed_computing',
#  'https://wikipedia.org/wiki/Digital_object_identifier',
#  'https://wikipedia.org#cite_ref-:2_40-4',
#  'https://wikipedia.org/wiki/Probably_approximately_correct_learning',
#  'https://wikipedia.org#cite_note-41',
#  'https://wikipedia.org/wiki/Predictive_modelling',
#  'https://wikipedia.org/wiki/Regression_analysis',
#  'https://wikipedia.org/wiki/Montpellier_2_University',
#  'https://wikipedia.org/wiki/Special:BookSources/0-12-241770-4',
#  'https://wikipedia.org/wiki/Datalogy',
#  'https://wikipedia.org/wiki/Hans_Rosling',
#  'https://wikipedia.org#cite_note-:3-3',
#  'https://wikipedia.org#cite_ref-43',
#  'https://wikipedia.org/w/index.php?title=Data_science&oldid=923200162',
#  'https://wikipedia.org#cite_note-17',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=edit&section=1',
#  'https://web.archive.org/web/20120403153707/https://www.jstage.jst.go.jp/browse/dsj/_vols',
#  'https://www.kdnuggets.com/2018/05/data-science-4-reasons-failing-deliver.html',
#  'https://wikipedia.org/wiki/Nate_Silver',
#  'https://wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding',
#  'https://wikipedia.org/wiki/International_Conference_on_Machine_Learning',
#  'https://wikipedia.org/wiki/Independent_component_analysis',
#  'https://wikipedia.org/wiki/Semi-supervised_learning',
#  'https://wikipedia.org#cite_ref-dsj12_26-0',
#  'https://wikipedia.org#cite_ref-14',
#  'https://datamining.it.uts.edu.au/conferences/dsaa14/',
#  'https://wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  'https://wikipedia.org//www.ncbi.nlm.nih.gov/pubmed/24436391',
#  'https://wikipedia.org/wiki/Database',
#  'https://wikipedia.org/wiki/DBSCAN',
#  'https://wikipedia.org#cite_ref-11',
#  'https://wikipedia.org/wiki/Health_science',
#  'https://wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Data+science',
#  'https://wikipedia.org#cite_ref-7',
#  'https://wikipedia.org/wiki/Linear_regression',
#  'https://wikipedia.org#cite_note-33',
#  'https://www.mediawiki.org/',
#  'https://wikipedia.org/wiki/Social_science',
#  'https://wikipedia.org#cite_ref-37',
#  'https://wikipedia.org#cite_ref-TansleyTolle2009_5-0',
#  'https://wikipedia.org/wiki/C.F._Jeff_Wu',
#  'https://wikipedia.org/wiki/PubMed_Central',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  'https://wikipedia.org#cite_note-Dinov_DSPA_2018-10',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=edit&section=3',
#  'https://wikipedia.org/wiki/Support-vector_machine',
#  'https://wikipedia.org#cite_note-GilPress-9',
#  'https://wikipedia.org/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Data+science',
#  'https://wikipedia.org/wiki/File:Kernel_Machine.svg',
#  'https://wikipedia.org/wiki/Methodology',
#  'https://wikipedia.org/wiki/Jeffrey_David_Ullman',
#  'https://wikipedia.org/wiki/Relevance_vector_machine',
#  'https://wikipedia.org//www.worldcat.org/issn/0960-3174',
#  'https://wikipedia.org#cite_note-32',
#  'https://wikipedia.org#cite_ref-Harvard_8-1',
#  'https://wikipedia.org/wiki/K-nearest_neighbors_algorithm',
#  'https://wikipedia.org/wiki/Statistical_learning_theory',
#  'https://en.wikipedia.org/w/index.php?title=Template:Machine_learning_bar&action=edit',
#  'https://wikipedia.org/wiki/David_Donoho',
#  'https://wikipedia.org/wiki/Decision_tree_learning',
#  'https://wikipedia.org/wiki/Computational_science',
#  'https://www.bbc.co.uk/programmes/b00wgq0l',
#  'https://wikipedia.org/wiki/The_Wall_Street_Journal',
#  'https://wikipedia.org/wiki/Machine_learning',
#  'https://wikipedia.org#cite_note-cfjwu01-22',
#  'https://wikipedia.org/wiki/Jure_Leskovec',
#  'https://wikipedia.org/wiki/Basic_research',
#  'https://wikipedia.org/wiki/The_Data_Incubator',
#  'https://wikipedia.org#cite_note-16',
#  'https://wikipedia.org#cite_ref-41',
#  'https://wikipedia.org/wiki/Analytics',
#  'https://wikipedia.org#cite_ref-30',
#  'https://wikipedia.org#cite_ref-:2_40-5',
#  'https://wikipedia.org/wiki/Data_mining',
#  'https://wikipedia.org/wiki/Dimensionality_reduction',
#  'https://wikipedia.org/wiki/Harvard_Business_Review',
#  'https://wikipedia.org/wiki/Conference_on_Neural_Information_Processing_Systems',
#  'https://www.forbes.com/sites/gilpress/2013/08/19/data-science-whats-the-half-life-of-a-buzzword/',
#  'https://wikipedia.org/wiki/Computational_learning_theory',
#  'https://wikipedia.org#cite_note-15',
#  'https://wikipedia.org/wiki/List_of_datasets_for_machine-learning_research',
#  'https://wikipedia.org/wiki/Mean-shift',
#  'https://wikipedia.org#cite_note-42',
#  'https://blogs.wsj.com/cio/2014/05/02/why-do-we-need-data-science-when-weve-had-statistics-for-centuries/',
#  'https://wikipedia.org//www.worldcat.org/issn/1465-4644',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=history',
#  'https://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/fulltext',
#  'https://wikipedia.org#cite_ref-31',
#  'https://wikipedia.org#cite_ref-42',
#  'https://wikipedia.org#cite_note-2',
#  'https://wikipedia.org#cite_ref-:0_1-0',
#  'https://wikipedia.org/wiki/Wikipedia:About',
#  'https://it.wikipedia.org/wiki/Scienza_dei_dati',
#  'https://wikipedia.org/wiki/Logistic_regression',
#  'https://wikipedia.org/wiki/Feature_learning',
#  'https://arxiv.org/list/cs.LG/recent',
#  'https://wikipedia.org#cite_ref-:2_40-7',
#  'https://ms.wikipedia.org/wiki/Sains_data',
#  'https://wikipedia.org/wiki/Boosting_(machine_learning)',
#  'https://wikipedia.org#cite_ref-Dinov_DSPA_2018_10-0',
#  'https://es.wikipedia.org/wiki/Ciencia_de_datos',
#  'https://de.wikipedia.org/wiki/Data_Science',
#  'https://wikipedia.org/wiki/Prasanta_Chandra_Mahalanobis',
#  'https://wikipedia.org/wiki/New_York_University',
#  'https://wikipedia.org/wiki/DJ_Patil',
#  'https://wikipedia.org/wiki/Wikipedia:File_Upload_Wizard',
#  'https://wikipedia.org#mw-head',
#  'https://wikipedia.org//creativecommons.org/licenses/by-sa/3.0/',
#  'https://wikipedia.org/wiki/Help:Contents',
#  'https://wikipedia.org/wiki/Category:Computer_occupations',
#  'https://wikipedia.org//www.ncbi.nlm.nih.gov/pmc/articles/PMC4058759',
#  'https://wikipedia.org/wiki/Grammar_induction',
#  'https://wikipedia.org#cite_ref-cleveland01_24-0',
#  'https://wikipedia.org/wiki/International_Standard_Book_Number',
#  'https://wikipedia.org#cite_note-14',
#  'https://wikipedia.org/wiki/Category:All_articles_with_unsourced_statements',
#  'https://wikipedia.org/wiki/Computing',
#  'https://wikipedia.org/wiki/Category:Use_dmy_dates_from_December_2012',
#  'https://wikipedia.org/wiki/Feature_engineering',
#  'https://wikipedia.org/wiki/OPTICS_algorithm',
#  'https://wikipedia.org/wiki/Artificial_neural_network',
#  'https://wikipedia.org/wiki/Data',
#  'https://wikipedia.org/wiki/Long_short-term_memory',
#  'https://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/',
#  'https://wikipedia.org/wiki/Deep_learning',
#  'https://id.wikipedia.org/wiki/Ilmu_data',
#  'https://wikipedia.org/wiki/Hidden_Markov_model',
#  'https://venturebeat.com/2014/04/15/ny-gets-new-bootcamp-for-data-scientists-its-free-but-harder-to-get-into-than-harvard/',
#  'https://wikipedia.org/wiki/Wayback_Machine',
#  'https://wikipedia.org/w/index.php?title=Data_science&action=edit&section=2',
#  'https://wikipedia.org/wiki/Help:Category',
#  'https://wikipedia.org#cite_note-:2-40',
#  'https://wikipedia.org#cite_ref-17',
#  'https://hbr.org/2018/01/are-you-setting-your-data-scientists-up-to-fail',
#  'https://wikipedia.org/wiki/Category:Webarchive_template_wayback_links',
#  'https://wikipedia.org/wiki/Principal_component_analysis',
#  'https://wikipedia.org/wiki/Restricted_Boltzmann_machine',
#  'https://wikipedia.org#cite_ref-:2_40-1',
#  'https://wikipedia.org#cite_note-Hayashi-4',
#  'https://www.isical.ac.in/~statmath/html/pcm/pcm_recent.html',
#  'https://wikipedia.org/wiki/Information_explosion',
#  'https://wikipedia.org/wiki/Data_set',
#  'https://wikipedia.org/wiki/Peter_Naur',
#  'https://wikipedia.org/wiki/International_Standard_Serial_Number']

# %% [markdown]
# ## Step 4: Use the os library to create a folder called *wikipedia* and make that the current working directory.

# %%
import os

# %%
#os.mkdir('wikipedia')
path = '/Users/svr/Documents/Ironhack/datamex1019/module-1/lab-parallelization/your-code/wikipedia'
os.chdir(path)

# %% [markdown]
# ## Step 5: Write a function called index_page that accepts a link and does the following.
#
# - Tries to request the content of the page referenced by that link.
# - Slugifies the filename using the `slugify` function from the [python-slugify](https://pypi.org/project/python-slugify/) library and adds a .html file extension.
#     - If you don't already have the python-slugify library installed, you can pip install it as follows: `$ pip install python-slugify`.
#     - To import the slugify function, you would do the following: `from slugify import slugify`.
#     - You can then slugify a link as follows `slugify(link)`.
# - Creates a file in the wikipedia folder using the slugified filename and writes the contents of the page to the file.
# - If an exception occurs during the process above, just `pass`.

# %%
from slugify import slugify

def index_page(link):
    try:
        html = requests.get(link).content
        slug = slugify(html)
        file = open('slugified', 'w')
        file = file.write(slug)
    except:
        pass

# %% [markdown]
# ## Step 6: Sequentially loop through the list of links, running the index_page function each time.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
# %%time
sequence = [index_page(i) for i in combine_2]
# Out:
# CPU times: user 53.6 s, sys: 3.67 s, total: 57.2 s
# Wall time: 5min 39s

# %% [markdown]
# ## Step 7: Perform the page indexing in parallel and note the difference in performance.
#
# Remember to include `%%time` at the beginning of the cell so that it measures the time it takes for the cell to run.

# %%
import multiprocessing

# %%
# %%time
pool = multiprocessing.Pool()
result = pool.map(index_page, combine_2)
pool.terminate()
pool.join()
# Out:
# CPU times: user 89.5 ms, sys: 42.6 ms, total: 132 ms
# Wall time: 1min 24s
